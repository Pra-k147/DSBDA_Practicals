# %%
name="Pratiksha"
emailaddress="Pune@gmail.com"
print("my name is:{name} and my mailing address is:{email}".format(name=name,email=emailaddress));
# Out:
# my name is:Pratiksha and my mailing address is:Pune@gmail.com

# %%
x=input("Enter yout name:")
print("hii {x}".format(x=x))
# Out:
# Enter yout name: Pratiksha
# hii Pratiksha

# %%
width=float(input("Enter the width of the room: "))
height=float(input("Enter the height of the room: "))
area=width * height
print("The width: {width} and height : {height},""then total area is {area}m".format(width=width,height=height,area=area))
# Out:
# Enter the width of the room:  20
# Enter the height of the room:  12
# The width: 20.0 and height : 12.0,then total area is 240.0m

# %%
sqperacre=43560
length=float(input("Enter the length: "))
width=float(input("Enter the width: "))
area=(length*width)/sqperacre
print("The length is {length},""the width is {width},""and the area is {area}".format(length=length,width=width,area=area))
# Out:
# Enter the length:  12
# Enter the width:  13
# The length is 12.0,the width is 13.0,and the area is 0.003581267217630854

# %%
less=0.10
more=0.25
less=int(input("Enter the number of container:"))
more=int(input("how many container more than 1:"))
refund=less*less+more*more
print("total refund:{}".format(refund))
# Out:
# Enter the number of container: 12
# how many container more than 1: 13
# total refund:313
