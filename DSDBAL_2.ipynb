# %%
import pandas as pd

# %%
import numpy as np

# %%
df=pd.read_csv("C:/Users/hppc2/Downloads/STUDENT_DATASET.csv")

# %%
df
# Out:
#     age     sex  Marks(400) Section name      City  percentage
# 0    19  female         300       A  AAA  Banglore       75.00
# 1    18    male         330       B  BBB      Pune       82.50
# 2    28    male         324       C  CDC    Mumbai       81.00
# 3    33    male         322       D  SDC     Delhi       80.50
# 4    32    male         240       A  SFG    Mumbai       60.00
# ..  ...     ...         ...     ...  ...       ...         ...
# 94   64  female         356       C  NMB      Pune       89.00
# 95   28  female         344       D  FDT     Delhi       86.00
# 96   54  female         245       A  TAM      Pune       61.25
# 97   55    male         388       B  GQP  Banglore       97.00
# 98   56    male         365       C  KKK      Pune       91.25
#
# [99 rows x 7 columns]

# %%
df.isnull()
# Out:
#       age    sex  Marks(400)  Section   name   City  percentage
# 0   False  False       False    False  False  False       False
# 1   False  False       False    False  False  False       False
# 2   False  False       False    False  False  False       False
# 3   False  False       False    False  False  False       False
# 4   False  False       False    False  False  False       False
# ..    ...    ...         ...      ...    ...    ...         ...
# 94  False  False       False    False  False  False       False
# 95  False  False       False    False  False  False       False
# 96  False  False       False    False  False  False       False
# 97  False  False       False    False  False  False       False
# 98  False  False       False    False  False  False       False
#
# [99 rows x 7 columns]

# %%
series=pd.isnull(df["age"])

# %%
df[series]
# Out:
# Empty DataFrame
# Columns: [age, sex, Marks(400), Section, name, City, percentage]
# Index: []

# %%
df.notnull()
# Out:
#      age   sex  Marks(400)  Section  name  City  percentage
# 0   True  True        True     True  True  True        True
# 1   True  True        True     True  True  True        True
# 2   True  True        True     True  True  True        True
# 3   True  True        True     True  True  True        True
# 4   True  True        True     True  True  True        True
# ..   ...   ...         ...      ...   ...   ...         ...
# 94  True  True        True     True  True  True        True
# 95  True  True        True     True  True  True        True
# 96  True  True        True     True  True  True        True
# 97  True  True        True     True  True  True        True
# 98  True  True        True     True  True  True        True
#
# [99 rows x 7 columns]

# %%
series1=pd.notnull(df["age"])

# %%
series1
# Out:
# 0     True
# 1     True
# 2     True
# 3     True
# 4     True
#       ...
# 94    True
# 95    True
# 96    True
# 97    True
# 98    True
# Name: age, Length: 99, dtype: bool

# %%
from sklearn.preprocessing import LabelEncoder

# %%
df1=pd.read_csv("C:/Users/hppc2/Downloads/StudentPerformanceFactors.csv")

# %%
df1
# Out:
#       Hours_Studied  Attendance Parental_Involvement Access_to_Resources  \
# 0                23          84                  Low                High
# 1                19          64                  Low              Medium
# 2                24          98               Medium              Medium
# 3                29          89                  Low              Medium
# 4                19          92               Medium              Medium
# ...             ...         ...                  ...                 ...
# 6602             25          69                 High              Medium
# 6603             23          76                 High              Medium
# 6604             20          90               Medium                 Low
# 6605             10          86                 High                High
# 6606             15          67               Medium                 Low
#
#      Extracurricular_Activities  Sleep_Hours  Previous_Scores  \
# ...

# %%
le = LabelEncoder()

# %%
df1['Internet_Access']=le.fit_transform(df1['Internet_Access'])

# %%
newdf=df1

# %%
df1
# Out:
#       Hours_Studied  Attendance Parental_Involvement Access_to_Resources  \
# 0                23          84                  Low                High
# 1                19          64                  Low              Medium
# 2                24          98               Medium              Medium
# 3                29          89                  Low              Medium
# 4                19          92               Medium              Medium
# ...             ...         ...                  ...                 ...
# 6602             25          69                 High              Medium
# 6603             23          76                 High              Medium
# 6604             20          90               Medium                 Low
# 6605             10          86                 High                High
# 6606             15          67               Medium                 Low
#
#      Extracurricular_Activities  Sleep_Hours  Previous_Scores  \
# ...

# %%
missing_values=["Na","na"]

# %%
a=pd.read_csv("C:/Users/hppc2/Downloads/StudentPerformanceFactors.csv",na_values=missing_values)

# %%
a
# Out:
#       Hours_Studied  Attendance Parental_Involvement Access_to_Resources  \
# 0                23          84                  Low                High
# 1                19          64                  Low              Medium
# 2                24          98               Medium              Medium
# 3                29          89                  Low              Medium
# 4                19          92               Medium              Medium
# ...             ...         ...                  ...                 ...
# 6602             25          69                 High              Medium
# 6603             23          76                 High              Medium
# 6604             20          90               Medium                 Low
# 6605             10          86                 High                High
# 6606             15          67               Medium                 Low
#
#      Extracurricular_Activities  Sleep_Hours  Previous_Scores  \
# ...

# %%
a.fillna(0)
# Out:
#       Hours_Studied  Attendance Parental_Involvement Access_to_Resources  \
# 0                23          84                  Low                High
# 1                19          64                  Low              Medium
# 2                24          98               Medium              Medium
# 3                29          89                  Low              Medium
# 4                19          92               Medium              Medium
# ...             ...         ...                  ...                 ...
# 6602             25          69                 High              Medium
# 6603             23          76                 High              Medium
# 6604             20          90               Medium                 Low
# 6605             10          86                 High                High
# 6606             15          67               Medium                 Low
#
#      Extracurricular_Activities  Sleep_Hours  Previous_Scores  \
# ...

# %%
m_v=df1['Sleep_Hours'].mean()

# %%
m_v
# Out:
# 7.029060087785682

# %%
b=df1['Sleep_Hours'].fillna(m_v)

# %%
b
# Out:
# 0       7
# 1       8
# 2       7
# 3       8
# 4       6
#        ..
# 6602    7
# 6603    8
# 6604    6
# 6605    6
# 6606    9
# Name: Sleep_Hours, Length: 6607, dtype: int64

# %%
c=df1.replace(to_replace=np.nan,value=-99)

# %%
c
# Out:
#       Hours_Studied  Attendance Parental_Involvement Access_to_Resources  \
# 0                23          84                  Low                High
# 1                19          64                  Low              Medium
# 2                24          98               Medium              Medium
# 3                29          89                  Low              Medium
# 4                19          92               Medium              Medium
# ...             ...         ...                  ...                 ...
# 6602             25          69                 High              Medium
# 6603             23          76                 High              Medium
# 6604             20          90               Medium                 Low
# 6605             10          86                 High                High
# 6606             15          67               Medium                 Low
#
#      Extracurricular_Activities  Sleep_Hours  Previous_Scores  \
# ...

# %%
d=df1.dropna()

# %%
d
# Out:
#       Hours_Studied  Attendance Parental_Involvement Access_to_Resources  \
# 0                23          84                  Low                High
# 1                19          64                  Low              Medium
# 2                24          98               Medium              Medium
# 3                29          89                  Low              Medium
# 4                19          92               Medium              Medium
# ...             ...         ...                  ...                 ...
# 6602             25          69                 High              Medium
# 6603             23          76                 High              Medium
# 6604             20          90               Medium                 Low
# 6605             10          86                 High                High
# 6606             15          67               Medium                 Low
#
#      Extracurricular_Activities  Sleep_Hours  Previous_Scores  \
# ...

# %%
e=df1.dropna(how='all')

# %%
e
# Out:
#       Hours_Studied  Attendance Parental_Involvement Access_to_Resources  \
# 0                23          84                  Low                High
# 1                19          64                  Low              Medium
# 2                24          98               Medium              Medium
# 3                29          89                  Low              Medium
# 4                19          92               Medium              Medium
# ...             ...         ...                  ...                 ...
# 6602             25          69                 High              Medium
# 6603             23          76                 High              Medium
# 6604             20          90               Medium                 Low
# 6605             10          86                 High                High
# 6606             15          67               Medium                 Low
#
#      Extracurricular_Activities  Sleep_Hours  Previous_Scores  \
# ...

# %%
f=df1.dropna(axis=1)

# %%
f
# Out:
#       Hours_Studied  Attendance Parental_Involvement Access_to_Resources  \
# 0                23          84                  Low                High
# 1                19          64                  Low              Medium
# 2                24          98               Medium              Medium
# 3                29          89                  Low              Medium
# 4                19          92               Medium              Medium
# ...             ...         ...                  ...                 ...
# 6602             25          69                 High              Medium
# 6603             23          76                 High              Medium
# 6604             20          90               Medium                 Low
# 6605             10          86                 High                High
# 6606             15          67               Medium                 Low
#
#      Extracurricular_Activities  Sleep_Hours  Previous_Scores  \
# ...

# %%
g=df1.dropna(axis=0,how='any')

# %%
g
# Out:
#       Hours_Studied  Attendance Parental_Involvement Access_to_Resources  \
# 0                23          84                  Low                High
# 1                19          64                  Low              Medium
# 2                24          98               Medium              Medium
# 3                29          89                  Low              Medium
# 4                19          92               Medium              Medium
# ...             ...         ...                  ...                 ...
# 6602             25          69                 High              Medium
# 6603             23          76                 High              Medium
# 6604             20          90               Medium                 Low
# 6605             10          86                 High                High
# 6606             15          67               Medium                 Low
#
#      Extracurricular_Activities  Sleep_Hours  Previous_Scores  \
# ...

# %%
import matplotlib.pyplot as plt

# %%
col=['Hours_Studied','Attendance','Previous_Scores']
